# %% [markdown]
# Importing the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Load the dataset

# %%
df=pd.read_csv("BostonHousing.csv")
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %% [markdown]
# 1) CRIM: per capita crime rate by town
# 2) ZN: proportion of residential land zoned for lots over 25,000 sq.ft.
# 3) INDUS: proportion of non-retail business acres per town
# 4) CHAS: Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# 5) NOX: nitric oxides concentration (parts per 10 million)
# 6) RM: average number of rooms per dwelling
# 7) AGE: proportion of owner-occupied units built prior to 1940
# 8) DIS: weighted distances to five Boston employment centres
# 9) RAD: index of accessibility to radial highways
# 10) TAX: full-value property-tax rate per $10,000
# 11) PTRATIO: pupil-teacher ratio by town
# 12) B: The result of the equation B=1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# 13) LSTAT: % lower status of the population
#
# Output variable: 1) MEDV: Median value of owner-occupied homes in $1000's

# %% [markdown]
# Finding the correlation between different columns
# #From the plot drawn below we can see some columns having very high correlation whereas some having negative correlation

# %%
corr_matrix=df.corr()

plt.figure(figsize=(12,8))
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm')
plt.title("Correlation between all the columns")
plt.show()

# %%
sns.histplot(df["medv"],kde=True)
plt.title("Distribution of median home values")
plt.xlabel("Median Home Value")
plt.ylabel("Frequency")
plt.show()

#From the plot it is evident that many homes have a median value of $20
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.scatterplot(x=df["crim"],y=df["medv"])
plt.title("Crime rates effect on house prices")
plt.xlabel("Crime rate")
plt.ylabel("Median Home Values")
plt.show()

# this plot is showing that at locations where crime rate is 0 the house prices are more showing people prefer locations 
  with less crime rate

# %%
sns.scatterplot(x=df["nox"],y=df["medv"])
plt.title("Nitric oxide effect on house prices")
plt.xlabel("Nitric oxide concentration")
plt.ylabel("Median Home Values")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['chas'], y=df['medv'])
plt.title("Boxplot of MEDV grouped by CHAS")
plt.xlabel("CHAS (1 = Near Charles River)")
plt.ylabel("Median House Price (MEDV)")
plt.show()

# %%
selected_features = ['medv', 'rm', 'lstat', 'crim', 'tax']
sns.pairplot(df[selected_features])
plt.title("Pairplot of Selected Features")
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
#Splitting of the dataset into X(input) and y(output)
X = df.iloc[:, :-1]
y = df['medv']

# %%
X
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# ...

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
#This boxplot is giving us the way the distribution of values is.
sns.boxplot(data=X)
plt.show()

# %%
##Splitting of entire dataset into train and test datasets with 70% as train dataset and 30% as test dataset and
##random state as 42 ensuring that the dataset is shuffled
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30, random_state=42)

# %%
# Standard scaler is used to standarize features.
# fit(): Computes the mean and standard deviation for scaling and transform(): Applies the transformation using those computed values.
#X_test must be transformed using the mean and standard deviation learned from X_train.

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaled_data=scaler.fit_transform(X_train)
X_train = pd.DataFrame(scaled_data, columns=X_train.columns)
scaled_data=scaler.transform(X_test)
X_test = pd.DataFrame(scaled_data, columns=X_test.columns)

# %%
sns.boxplot(data=X_train)
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(data=X_test)
plt.xticks(rotation=90)
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
# This model assumes a linear relationship between independent variables (X_train) and the target variable (y_train).
# The .fit() function trains the linear regression model using X_train (features) and y_train (target).
regression=LinearRegression()
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#prediction on the test data
reg_pred=regression.predict(X_test)

# %%
reg_pred
# Out:
# array([28.64896005, 36.49501384, 15.4111932 , 25.40321303, 18.85527988,
#        23.14668944, 17.3921241 , 14.07859899, 23.03692679, 20.59943345,
#        24.82286159, 18.53057049, -6.86543527, 21.80172334, 19.22571177,
#        26.19191985, 20.27733882,  5.61596432, 40.44887974, 17.57695918,
#        27.44319095, 30.1715964 , 10.94055823, 24.02083139, 18.07693812,
#        15.934748  , 23.12614028, 14.56052142, 22.33482544, 19.3257627 ,
#        22.16564973, 25.19476081, 25.31372473, 18.51345025, 16.6223286 ,
#        17.50268505, 30.94992991, 20.19201752, 23.90440431, 24.86975466,
#        13.93767876, 31.82504715, 42.56978796, 17.62323805, 27.01963242,
#        17.19006621, 13.80594006, 26.10356557, 20.31516118, 30.08649576,
#        21.3124053 , 34.15739602, 15.60444981, 26.11247588, 39.31613646,
#        22.99282065, 18.95764781, 33.05555669, 24.85114223, 12.91729352,
#        22.68101452, 30.80336295, 31.63522027, 16.29833689, 21.07379993,
# ...

# %%
reg_diff = pd.DataFrame({'Actual value': y_test, 'Predicted value': reg_pred})
reg_diff.head()
# Out:
#      Actual value  Predicted value
# 173          23.6        28.648960
# 274          32.4        36.495014
# 491          13.6        15.411193
# 72           22.8        25.403213
# 452          16.1        18.855280

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
# This is used to measure how well the regression model fits the data using metrics 

mae= mean_absolute_error(y_test,reg_pred)
mse= mean_squared_error(y_test,reg_pred)
r2= r2_score(y_test,reg_pred)
rmse=np.sqrt(mean_squared_error(y_test,reg_pred))
print("Mean absolute error:",mae)
print("Mean squared error:",mse)
print("R squared error:",r2)
print("Root mean squared error:",rmse)
# Out:
# Mean absolute error: 3.1627098714574053
# Mean squared error: 21.517444231177205
# R squared error: 0.7112260057484934
# Root mean squared error: 4.6386899261728205
